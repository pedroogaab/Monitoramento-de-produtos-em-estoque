# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroogaab/Monitoramento-de-produtos-em-estoque/blob/main/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Check if the GPU is in use
# !nvidia-smi
# Out:
# Thu Nov  6 11:34:33 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
#Connect with google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics
import os
from IPython.display import Image, display
from IPython import display
from ultralytics import YOLO

display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 910, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {list(MODES)}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.12/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ['val', 'predict', 'track', 'benchmark', 'train', 'export'].
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['pose', 'segment', 'classify', 'detect', 'obb']
#                 MODE (required) is one of ['val', 'predict', 'track', 'benchmark', 'train', 'export']
# ...

# %%
current_lote = 1 #specify currently lote to train
current_lote_path = f"/content/drive/MyDrive/visao_computacional/dataset/lote{current_lote}"
print(current_lote_path)

#Example for usage a custom data.yaml
'''
train: images/train
val: images/val
test: images/test

nc: 1
names: ['Product']
'''
# Out:
# /content/drive/MyDrive/visao_computacional/dataset/lote1
# "\ntrain: images/train\nval: images/val\ntest: images/test\n\nnc: 1\nnames: ['Product']\n"

# %%
# !cat "{current_lote_path}/data.yaml"
# Out:
# train: images/train
# val: images/val
# test: images/test
#
# nc: 1
# names: ['Product']

# %%
#Train current lote
# !yolo task=detect mode=train model=yolov8n.pt data="{current_lote_path}/data.yaml" epochs=80 imgsz=640
# !mv /content/runs {current_lote_path} #for move to drive when finaly train
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...
